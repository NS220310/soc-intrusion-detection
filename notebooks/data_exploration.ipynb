# %%
import pandas as pd

train_df = pd.read_csv("C:/Users/Dell/Desktop/soc-intrusion detection/data/raw/UNSW_NB15_training-set.csv")
test_df  = pd.read_csv("C:/Users/Dell/Desktop/soc-intrusion detection/data/raw/UNSW_NB15_testing-set.csv")

print("Train shape:", train_df.shape)
print("Test shape:", test_df.shape)
# Out:
# Train shape: (82332, 45)
# Test shape: (175341, 45)

# %%
print("Training file rows:", train_df.shape[0])
print("Testing file rows:", test_df.shape[0])

print("\nTraining label distribution:")
print(train_df["label"].value_counts())

print("\nTesting label distribution:")
print(test_df["label"].value_counts())
# Out:
# Training file rows: 82332
# Testing file rows: 175341
#
# Training label distribution:
# label
# 1    45332
# 0    37000
# Name: count, dtype: int64
#
# Testing label distribution:
# label
# 1    119341
# 0     56000
# Name: count, dtype: int64

# %%
import pandas as pd

df_small = pd.read_csv(
    "C:/Users/Dell/Desktop/soc-intrusion detection/data/raw/UNSW_NB15_training-set.csv"
)

df_large = pd.read_csv(
    "C:/Users/Dell/Desktop/soc-intrusion detection/data/raw/UNSW_NB15_testing-set.csv"
)

# Assign based on SIZE, not filename
train_df = df_large   # 175,341 rows
test_df  = df_small   # 82,332 rows

print("Final TRAIN shape:", train_df.shape)
print("Final TEST shape:", test_df.shape)
# Out:
# Final TRAIN shape: (175341, 45)
# Final TEST shape: (82332, 45)

# %%
print("Columns match:", train_df.columns.equals(test_df.columns))
# Out:
# Columns match: True

# %%
print("Binary label distribution (TRAIN):")
print(train_df["label"].value_counts())

print("\nBinary label distribution (TEST):")
print(test_df["label"].value_counts())
# Out:
# Binary label distribution (TRAIN):
# label
# 1    119341
# 0     56000
# Name: count, dtype: int64
#
# Binary label distribution (TEST):
# label
# 1    45332
# 0    37000
# Name: count, dtype: int64

# %%
print("Attack categories (TRAIN):")
print(train_df["attack_cat"].value_counts())
# Out:
# Attack categories (TRAIN):
# attack_cat
# Normal            56000
# Generic           40000
# Exploits          33393
# Fuzzers           18184
# DoS               12264
# Reconnaissance    10491
# Analysis           2000
# Backdoor           1746
# Shellcode          1133
# Worms               130
# Name: count, dtype: int64

# %%
categorical_cols = train_df.select_dtypes(include="object").columns
numerical_cols = train_df.select_dtypes(exclude="object").columns

print("Categorical columns:", categorical_cols)
print("Numerical columns count:", len(numerical_cols))
# Out:
# Categorical columns: Index(['proto', 'service', 'state', 'attack_cat'], dtype='object')
# Numerical columns count: 41

# %%
train_df.isnull().sum().sort_values(ascending=False)
# Out:
# id                   0
# dwin                 0
# synack               0
# ackdat               0
# smean                0
# dmean                0
# trans_depth          0
# response_body_len    0
# ct_srv_src           0
# ct_state_ttl         0
# ct_dst_ltm           0
# ct_src_dport_ltm     0
# ct_dst_sport_ltm     0
# ct_dst_src_ltm       0
# is_ftp_login         0
# ct_ftp_cmd           0
# ct_flw_http_mthd     0
# ct_src_ltm           0
# ct_srv_dst           0
# is_sm_ips_ports      0
# attack_cat           0
# tcprtt               0
# dtcpb                0
# dur                  0
# stcpb                0
# proto                0
# service              0
# state                0
# spkts                0
# dpkts                0
# sbytes               0
# dbytes               0
# rate                 0
# sttl                 0
# dttl                 0
# sload                0
# dload                0
# sloss                0
# dloss                0
# sinpkt               0
# ...

# %%
import sys
print(sys.executable)
# Out:
# c:\Program Files\Python312\python.exe
